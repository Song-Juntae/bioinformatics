# %%
import requests
import json

from collections import Counter

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import cm

import networkx as nx

from Bio import Entrez

# %%
df_food = pd.read_csv('/home/sjt/space/github/bioinformatics/data/foodb_2020_04_07_csv/Food.csv')
df_food
# Out:
#        id             name                 name_scientific  \
# 0       1         Angelica                Angelica keiskei
# 1       2    Savoy cabbage  Brassica oleracea var. sabauda
# 2       3    Silver linden                  Tilia argentea
# 3       4             Kiwi             Actinidia chinensis
# 4       5           Allium                          Allium
# ..    ...              ...                             ...
# 987  1020  Cape gooseberry              Physalis peruviana
# 988  1021       Herbal tea                             NaN
# 989  1022         Fish oil                             NaN
# 990  1023       Taco shell                             NaN
# 991  1024    Tostada shell                             NaN
#
#                                            description   itis_id  \
# 0    Angelica is a genus of about 60 species of tal...       NaN
# 1    Savoy cabbage (Brassica oleracea convar. capit...       NaN
# 2    Tilia tomentosa (Silver Lime in the UK and Sil...  845789.0
# 3    The kiwifruit, often shortened to kiwi in many...  506775.0
# 4    Allium haematochiton is a species of wild onio...   42634.0
# ..                                                 ...       ...
# 987  Physalis peruviana, a plant species of the gen...       NaN
# 988  Herbal teas are the beverages made from the in...       NaN
# 989  Fish oil is oil derived from the tissues of oi...       NaN
# 990  The hard-shell or crispy taco is a tradition t...       NaN
# 991                                                NaN       NaN
#
#              wikipedia_id picture_file_name picture_content_type  \
# 0                Angelica             1.jpg           image/jpeg
# 1           Savoy cabbage             2.jpg           image/jpeg
# 2         Tilia tomentosa             3.jpg           image/jpeg
# 3               Kiwifruit             4.jpg           image/jpeg
# 4    Allium haematochiton             5.jpg           image/jpeg
# ..                    ...               ...                  ...
# 987                   NaN               NaN                  NaN
# 988                   NaN               NaN                  NaN
# 989                   NaN               NaN                  NaN
# 990                   NaN               NaN                  NaN
# 991                   NaN               NaN                  NaN
#
#      picture_file_size       picture_updated_at  ...  food_type  \
# 0             111325.0  2012-04-20 09:29:57 UTC  ...     Type 1
# 1             155178.0  2012-04-20 09:39:54 UTC  ...     Type 1
# 2              56367.0  2012-04-20 09:41:25 UTC  ...     Type 1
# 3             110661.0  2012-04-20 09:32:21 UTC  ...     Type 1
# 4             341911.0  2012-04-20 09:37:44 UTC  ...     Type 1
# ..                 ...                      ...  ...        ...
# 987                NaN                      NaN  ...     Type 1
# 988                NaN                      NaN  ...     Type 1
# 989                NaN                      NaN  ...     Type 1
# 990                NaN                      NaN  ...     Type 2
# 991                NaN                      NaN  ...     Type 2
#
#                   created_at               updated_at creator_id updater_id  \
# 0    2011-02-09 00:37:14 UTC  2019-05-14 18:04:13 UTC        NaN        2.0
# 1    2011-02-09 00:37:15 UTC  2019-05-14 18:04:13 UTC        NaN        NaN
# 2    2011-02-09 00:37:15 UTC  2019-05-17 16:19:45 UTC        NaN        NaN
# 3    2011-02-09 00:37:15 UTC  2019-05-14 18:04:13 UTC        NaN        NaN
# 4    2011-02-09 00:37:15 UTC  2019-05-14 18:04:13 UTC        NaN        NaN
# ..                       ...                      ...        ...        ...
# 987  2020-01-24 17:05:37 UTC  2020-01-24 17:05:37 UTC        NaN        NaN
# 988  2020-03-12 20:55:17 UTC  2020-03-12 20:55:17 UTC        NaN        NaN
# 989  2020-03-12 21:00:02 UTC  2020-03-12 21:00:02 UTC        NaN        NaN
# 990  2020-03-12 21:01:58 UTC  2020-03-12 21:01:58 UTC        NaN        NaN
# 991  2020-03-12 21:01:58 UTC  2020-03-12 21:01:58 UTC        NaN        NaN
#
#     export_to_afcdb  category  ncbi_taxonomy_id  export_to_foodb  public_id
# 0             False  specific          357850.0             True  FOOD00001
# 1             False  specific         1216010.0             True  FOOD00002
# 2             False  specific               NaN             True  FOOD00003
# 3             False  specific            3625.0             True  FOOD00004
# 4             False  specific            4678.0             True  FOOD00005
# ..              ...       ...               ...              ...        ...
# 987           False       NaN               NaN             True  FOOD00988
# 988           False       NaN               NaN             True  FOOD00989
# 989           False       NaN               NaN             True  FOOD00990
# 990           False       NaN               NaN             True  FOOD00991
# 991           False       NaN               NaN             True  FOOD00992
#
# [992 rows x 23 columns]

# %%
df_food.columns
# Out:
# Index(['id', 'name', 'name_scientific', 'description', 'itis_id',
#        'wikipedia_id', 'picture_file_name', 'picture_content_type',
#        'picture_file_size', 'picture_updated_at', 'legacy_id', 'food_group',
#        'food_subgroup', 'food_type', 'created_at', 'updated_at', 'creator_id',
#        'updater_id', 'export_to_afcdb', 'category', 'ncbi_taxonomy_id',
#        'export_to_foodb', 'public_id'],
#       dtype='object')

# %%
set(df_food['food_group'])
# Out:
# {'Animal foods',
#  'Aquatic foods',
#  'Baby foods',
#  'Baking goods',
#  'Beverages',
#  'Cereals and cereal products',
#  'Cocoa and cocoa products',
#  'Coffee and coffee products',
#  'Confectioneries',
#  'Dishes',
#  'Eggs',
#  'Fats and oils',
#  'Fruits',
#  'Gourds',
#  'Herbs and Spices',
#  'Herbs and spices',
#  'Milk and milk products',
#  'Nuts',
#  'Pulses',
#  'Snack foods',
#  'Soy',
#  'Teas',
#  'Unclassified',
#  'Vegetables',
#  nan}

# %%
m1 = df_food['food_group'] == 'Herbs and Spices'
m2 = df_food['food_group'] == 'Herbs and spices'

m = m1 | m2

df_food[m]
# Out:
#       id            name       name_scientific  \
# 0      1        Angelica      Angelica keiskei
# 2      3   Silver linden        Tilia argentea
# 7      8          Garlic        Allium sativum
# 8      9          Chives  Allium schoenoprasum
# 9     10   Lemon verbena     Aloysia triphylla
# ..   ...             ...                   ...
# 942  975  Cottonseed oil                   NaN
# 943  976        Corn oil                   NaN
# 944  977     Avocado oil                   NaN
# 945  978   Grapeseed oil                   NaN
# 946  979      Sesame oil                   NaN
#
#                                            description   itis_id  \
# 0    Angelica is a genus of about 60 species of tal...       NaN
# 2    Tilia tomentosa (Silver Lime in the UK and Sil...  845789.0
# 7    With a history of human use of over 7,000 year...   42652.0
# 8    Chives is the common name of Allium schoenopra...   42636.0
# 9    Aloysia citrodora is a species of flowering pl...   32135.0
# ..                                                 ...       ...
# 942  Cottonseed oil is cooking oil from the seeds o...       NaN
# 943  Corn oil (maize oil) is oil extracted from the...       NaN
# 944  Avocado oil is an edible oil pressed from the ...       NaN
# 945  Grape seed oil (also called grapeseed oil or g...       NaN
# 946  Sesame oil is an edible vegetable oil derived ...       NaN
#
#           wikipedia_id picture_file_name picture_content_type  \
# 0             Angelica             1.jpg           image/jpeg
# 2      Tilia tomentosa             3.jpg           image/jpeg
# 7               Garlic             8.jpg           image/jpeg
# 8               Chives             9.jpg           image/jpeg
# 9    Aloysia citrodora            10.jpg           image/jpeg
# ..                 ...               ...                  ...
# 942                NaN               NaN                  NaN
# 943                NaN               NaN                  NaN
# 944                NaN               NaN                  NaN
# 945                NaN               NaN                  NaN
# 946                NaN               NaN                  NaN
#
#      picture_file_size       picture_updated_at  ...  food_type  \
# 0             111325.0  2012-04-20 09:29:57 UTC  ...     Type 1
# 2              56367.0  2012-04-20 09:41:25 UTC  ...     Type 1
# 7             545294.0  2012-04-20 09:42:05 UTC  ...     Type 1
# 8            1411537.0  2012-04-20 09:42:09 UTC  ...     Type 1
# 9             142723.0  2012-04-20 09:32:16 UTC  ...     Type 1
# ..                 ...                      ...  ...        ...
# 942                NaN                      NaN  ...     Type 2
# 943                NaN                      NaN  ...     Type 2
# 944                NaN                      NaN  ...     Type 2
# 945                NaN                      NaN  ...     Type 2
# 946                NaN                      NaN  ...     Type 2
#
#                   created_at               updated_at creator_id updater_id  \
# 0    2011-02-09 00:37:14 UTC  2019-05-14 18:04:13 UTC        NaN        2.0
# 2    2011-02-09 00:37:15 UTC  2019-05-17 16:19:45 UTC        NaN        NaN
# 7    2011-02-09 00:37:15 UTC  2019-05-14 18:04:13 UTC        NaN        2.0
# 8    2011-02-09 00:37:15 UTC  2019-05-14 18:04:13 UTC        NaN        NaN
# 9    2011-02-09 00:37:15 UTC  2019-05-14 18:04:13 UTC        NaN        NaN
# ..                       ...                      ...        ...        ...
# 942  2020-01-24 17:05:36 UTC  2020-01-24 17:05:36 UTC        NaN        NaN
# 943  2020-01-24 17:05:36 UTC  2020-01-24 17:05:36 UTC        NaN        NaN
# 944  2020-01-24 17:05:36 UTC  2020-01-24 17:05:36 UTC        NaN        NaN
# 945  2020-01-24 17:05:36 UTC  2020-01-24 17:05:36 UTC        NaN        NaN
# 946  2020-01-24 17:05:36 UTC  2020-01-24 17:05:36 UTC        NaN        NaN
#
#     export_to_afcdb  category  ncbi_taxonomy_id  export_to_foodb  public_id
# 0             False  specific          357850.0             True  FOOD00001
# 2             False  specific               NaN             True  FOOD00003
# 7              True  specific            4682.0             True  FOOD00008
# 8             False  specific           74900.0             True  FOOD00009
# 9             False  specific          542672.0             True  FOOD00010
# ..              ...       ...               ...              ...        ...
# 942           False       NaN               NaN             True  FOOD00943
# 943           False       NaN               NaN             True  FOOD00944
# 944           False       NaN               NaN             True  FOOD00945
# 945           False       NaN               NaN             True  FOOD00946
# 946           False       NaN               NaN             True  FOOD00947
#
# [127 rows x 23 columns]
